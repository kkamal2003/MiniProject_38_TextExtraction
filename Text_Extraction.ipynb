# %% [markdown]
# <a href="https://colab.research.google.com/github/kkamal2003/MiniProject_38_TextExtraction/blob/main/Text_Extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Text Extraction from any file type

# %% [markdown]
# #1
# ##Install various libraries
# We may use few of them but these are for your future refrances.

# %%
# !pip install PyPDF2  # Install PyPDF2 library for working with PDF files
# !pip install textract  # Install textract library for extracting text from various file formats
# !pip install pytesseract  # Install pytesseract library for optical character recognition (OCR)
# !apt-get install tesseract-ocr  # Install Tesseract OCR engine
# !apt-get install libtesseract-dev  # Install Tesseract development libraries
# !pip install pytesseract  # Install pytesseract Python wrapper for Tesseract OCR
# !pip install textract  # Install textract library for text extraction from various file types
# !pip install pdf2image  # Install pdf2image library for converting PDFs to images
# !apt-get install poppler-utils  # Install poppler-utils for working with PDFs and extracting text
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting textract
#   Downloading textract-1.6.5-py3-none-any.whl (23 kB)
# Collecting argcomplete~=1.10.0 (from textract)
#   Downloading argcomplete-1.10.3-py2.py3-none-any.whl (36 kB)
# Collecting beautifulsoup4~=4.8.0 (from textract)
#   Downloading beautifulsoup4-4.8.2-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 10.9 MB/s eta 0:00:00
# Collecting chardet==3.* (from textract)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 12.6 MB/s eta 0:00:00
# Collecting docx2txt~=0.8 (from textract)
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting extract-msg<=0.29.* (from textract)
#   Downloading extract_msg-0.28.7-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 7.0 MB/s eta 0:00:00
# Collecting pdfminer.six==20191110 (from textract)
#   Downloading pdfminer.six-20191110-py2.py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.1 MB/s eta 0:00:00
# Collecting python-pptx~=0.6.18 (from textract)
#   Downloading python-pptx-0.6.21.tar.gz (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 132.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting six~=1.12.0 (from textract)
#   Downloading six-1.12.0-py2.py3-none-any.whl (10 kB)
# Collecting SpeechRecognition~=3.8.1 (from textract)
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 16.8 MB/s eta 0:00:00
# Collecting xlrd~=1.2.0 (from textract)
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 11.8 MB/s eta 0:00:00
# Collecting pycryptodome (from pdfminer.six==20191110->textract)
#   Downloading pycryptodome-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 68.2 MB/s eta 0:00:00
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.4.1)
# Collecting imapclient==2.1.0 (from extract-msg<=0.29.*->textract)
#   Downloading IMAPClient-2.1.0-py2.py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 8.7 MB/s eta 0:00:00
# Collecting olefile>=0.46 (from extract-msg<=0.29.*->textract)
#   Downloading olefile-0.46.zip (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.0.1)
# Collecting compressed-rtf>=1.0.6 (from extract-msg<=0.29.*->textract)
#   Downloading compressed_rtf-1.0.6.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ebcdic>=1.1.1 (from extract-msg<=0.29.*->textract)
#   Downloading ebcdic-1.1.1-py2.py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.5/128.5 kB 15.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx~=0.6.18->textract)
#   Downloading XlsxWriter-3.1.2-py3-none-any.whl (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.0/153.0 kB 17.6 MB/s eta 0:00:00
# Building wheels for collected packages: docx2txt, python-pptx, compressed-rtf, olefile
#   Building wheel for docx2txt (setup.py) ... done
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3957 sha256=5b753a48c039321d72330d3a4fe2c74ff984f7dc87f3d4aef4a46d7b18257533
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
#   Building wheel for python-pptx (setup.py) ... done
#   Created wheel for python-pptx: filename=python_pptx-0.6.21-py3-none-any.whl size=470935 sha256=680a539821cff78703bc03123731a371c949648e2f7238864daea6bc12ec905b
#   Stored in directory: /root/.cache/pip/wheels/ea/dd/74/01b3ec7256a0800b99384e9a0f7620e358afc3a51a59bf9b49
#   Building wheel for compressed-rtf (setup.py) ... done
#   Created wheel for compressed-rtf: filename=compressed_rtf-1.0.6-py3-none-any.whl size=6185 sha256=f5da5c8177024783fed1cf1a50b33d736e68c2a7d5d1db126271971ce48e6c29
#   Stored in directory: /root/.cache/pip/wheels/15/3e/48/e7d833ecc516c36f8966d310b1a6386db091a718f1ff3bf85c
#   Building wheel for olefile (setup.py) ... done
#   Created wheel for olefile: filename=olefile-0.46-py2.py3-none-any.whl size=35417 sha256=8084d01131e89bbc01bf1878c48fa8e2fed2511d91649ad3c93f387508cad4af
#   Stored in directory: /root/.cache/pip/wheels/02/39/c0/9eb1f7a42b4b38f6f333b6314d4ed11c46f12a0f7b78194f0d
# Successfully built docx2txt python-pptx compressed-rtf olefile
# Installing collected packages: SpeechRecognition, ebcdic, docx2txt, compressed-rtf, chardet, argcomplete, XlsxWriter, xlrd, six, pycryptodome, olefile, beautifulsoup4, python-pptx, pdfminer.six, imapclient, extract-msg, textract
#   Attempting uninstall: chardet
#     Found existing installation: chardet 4.0.0
#     Uninstalling chardet-4.0.0:
#       Successfully uninstalled chardet-4.0.0
#   Attempting uninstall: xlrd
#     Found existing installation: xlrd 2.0.1
#     Uninstalling xlrd-2.0.1:
#       Successfully uninstalled xlrd-2.0.1
#   Attempting uninstall: six
#     Found existing installation: six 1.16.0
#     Uninstalling six-1.16.0:
#       Successfully uninstalled six-1.16.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.21 requires beautifulsoup4>=4.11.1, but you have beautifulsoup4 4.8.2 which is incompatible.
# Successfully installed SpeechRecognition-3.8.1 XlsxWriter-3.1.2 argcomplete-1.10.3 beautifulsoup4-4.8.2 chardet-3.0.4 compressed-rtf-1.0.6 docx2txt-0.8 ebcdic-1.1.1 extract-msg-0.28.7 imapclient-2.1.0 olefile-0.46 pdfminer.six-20191110 pycryptodome-3.18.0 python-pptx-0.6.21 six-1.12.0 textract-1.6.5 xlrd-1.2.0
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (8.4.0)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 15 not upgraded.
# Need to get 4,850 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1 [1,598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr amd64 4.1.1-2build2 [262 kB]
# Fetched 4,850 kB in 0s (27.4 MB/s)
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 123069 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_1%3a4.00~git30-7274cfa-1_all.deb ...
# Unpacking tesseract-ocr-eng (1:4.00~git30-7274cfa-1) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_1%3a4.00~git30-7274cfa-1_all.deb ...
# Unpacking tesseract-ocr-osd (1:4.00~git30-7274cfa-1) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.1.1-2build2_amd64.deb ...
# Unpacking tesseract-ocr (4.1.1-2build2) ...
# Setting up tesseract-ocr-eng (1:4.00~git30-7274cfa-1) ...
# Setting up tesseract-ocr-osd (1:4.00~git30-7274cfa-1) ...
# Setting up tesseract-ocr (4.1.1-2build2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libarchive-dev libleptonica-dev
# The following NEW packages will be installed:
#   libarchive-dev libleptonica-dev libtesseract-dev
# 0 upgraded, 3 newly installed, 0 to remove and 15 not upgraded.
# Need to get 3,343 kB of archives.
# After this operation, 15.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 libarchive-dev amd64 3.4.0-2ubuntu1.2 [491 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libleptonica-dev amd64 1.79.0-1 [1,389 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 libtesseract-dev amd64 4.1.1-2build2 [1,463 kB]
# Fetched 3,343 kB in 0s (20.9 MB/s)
# Selecting previously unselected package libarchive-dev:amd64.
# (Reading database ... 123116 files and directories currently installed.)
# Preparing to unpack .../libarchive-dev_3.4.0-2ubuntu1.2_amd64.deb ...
# Unpacking libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Selecting previously unselected package libleptonica-dev:amd64.
# Preparing to unpack .../libleptonica-dev_1.79.0-1_amd64.deb ...
# Unpacking libleptonica-dev:amd64 (1.79.0-1) ...
# Selecting previously unselected package libtesseract-dev:amd64.
# Preparing to unpack .../libtesseract-dev_4.1.1-2build2_amd64.deb ...
# Unpacking libtesseract-dev:amd64 (4.1.1-2build2) ...
# Setting up libleptonica-dev:amd64 (1.79.0-1) ...
# Setting up libarchive-dev:amd64 (3.4.0-2ubuntu1.2) ...
# Setting up libtesseract-dev:amd64 (4.1.1-2build2) ...
# Processing triggers for man-db (2.9.1-1) ...
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.10/dist-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (23.1)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from pytesseract) (8.4.0)
# Requirement already satisfied: textract in /usr/local/lib/python3.10/dist-packages (1.6.5)
# Requirement already satisfied: argcomplete~=1.10.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.10.3)
# Requirement already satisfied: beautifulsoup4~=4.8.0 in /usr/local/lib/python3.10/dist-packages (from textract) (4.8.2)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.10/dist-packages (from textract) (3.0.4)
# Requirement already satisfied: docx2txt~=0.8 in /usr/local/lib/python3.10/dist-packages (from textract) (0.8)
# Requirement already satisfied: extract-msg<=0.29.* in /usr/local/lib/python3.10/dist-packages (from textract) (0.28.7)
# Requirement already satisfied: pdfminer.six==20191110 in /usr/local/lib/python3.10/dist-packages (from textract) (20191110)
# Requirement already satisfied: python-pptx~=0.6.18 in /usr/local/lib/python3.10/dist-packages (from textract) (0.6.21)
# Requirement already satisfied: six~=1.12.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.12.0)
# Requirement already satisfied: SpeechRecognition~=3.8.1 in /usr/local/lib/python3.10/dist-packages (from textract) (3.8.1)
# Requirement already satisfied: xlrd~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from textract) (1.2.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (3.18.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20191110->textract) (2.4.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4~=4.8.0->textract) (2.4.1)
# Requirement already satisfied: imapclient==2.1.0 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (2.1.0)
# Requirement already satisfied: olefile>=0.46 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (0.46)
# Requirement already satisfied: tzlocal>=2.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (5.0.1)
# Requirement already satisfied: compressed-rtf>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.0.6)
# Requirement already satisfied: ebcdic>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from extract-msg<=0.29.*->textract) (1.1.1)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (4.9.2)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (8.4.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from python-pptx~=0.6.18->textract) (3.1.2)
# Collecting pdf2image
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from pdf2image) (8.4.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.16.3
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 15 not upgraded.
# Need to get 174 kB of archives.
# After this operation, 754 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 poppler-utils amd64 0.86.1-0ubuntu1.1 [174 kB]
# Fetched 174 kB in 0s (2,047 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 123247 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.86.1-0ubuntu1.1_amd64.deb ...
# Unpacking poppler-utils (0.86.1-0ubuntu1.1) ...
# Setting up poppler-utils (0.86.1-0ubuntu1.1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %% [markdown]
# #2
# ##Import the required libraries

# %%
from PyPDF2 import PdfReader  # Import PdfReader class from PyPDF2 library for reading PDF files
import pytesseract  # Import pytesseract library for OCR (text extraction from images)
from PIL import Image  # Import Image class from Pillow library for image manipulation
import textract  # Import textract library for text extraction from various file formats

# %% [markdown]
# #3
# ##Text extraction from Pdf

# %%
def extract_text_from_pdf(pdf_path):
    text = ""  # Initialize an empty string to store the extracted text
    with open(pdf_path, 'rb') as file:  # Open the PDF file in read-binary mode
        reader = PdfReader(file)  # Create a PDF reader object
        for page in reader.pages:  # Iterate through each page in the PDF
            text += page.extract_text()  # Extract the text from the current page and append it to the 'text' variable
    return text  # Return the extracted text

# %% [markdown]
# #4
# ##Text extraction from Image

# %%
def extract_text_from_image(image_path):
    image = Image.open(image_path)  # Open the image file using PIL's Image class
    text = pytesseract.image_to_string(image)  # Use pytesseract to extract text from the image
    return text  # Return the extracted text

# %% [markdown]
# #5
# ##Text extraction from any file type.

# %%
def extract_text_from_other(file_path):
    text = textract.process(file_path)  # Use textract to extract text from the file
    return text.decode('utf-8')  # Decode the extracted text from bytes to UTF-8 string

# %% [markdown]
# #6
# ##Main function redirection to above function based upon file type

# %%
def extract_text_from_file(file_path):
    if file_path.lower().endswith('.pdf'):  # If the file is a PDF
        return extract_text_from_pdf(file_path)  # Extract text from the PDF file
    elif file_path.lower().endswith(('.jpg', '.jpeg', '.png', '.gif', '.webp')):  # If the file is an image
        return extract_text_from_image(file_path)  # Extract text from the image file
    else:  # For other file types such as csv, word document etc
        return extract_text_from_other(file_path)  # Extract text using other methods

# %% [markdown]
# #7
# ##Upload file path
# ##Send file to above main function
# ##And wait for output
# Try uploading random images or Open Github repository https://github.com/gurtaransingh/scraping and open sample files folder.

# %%
file_path = '/content/prescription.pdf'
extracted_text = extract_text_from_file(file_path)
print(extracted_text)
# Out:
# Date: 27/05/2023
# Mr. Singh
# M.D Cardiology
# Phase 2, Urban Estate
# Reg. No. 102003
# 58732892378
# Mr. Singh
# M.D Cardiology
# Reg. No. 102003
#  Made by Prescription MakerMs. Patient
# DOB: 19/08/2003
# Age: 19 yrs
# Gender: Female
# Phase 3, Urban Estate
# 41287380989
# Height: 5.3 ft
# Weight: 65 kg
# Diagnosis: Diagnosis
# Chief Complaints
# Chief Complaints
# Clinical Features
# Clinical Features
# Examination
# Examination
# • Tab. Paracetamol 25 mg 2 unit Topical After meals Twice daily 7 days --- 14
# Other Instructions
# InvestigationsDate: 27/05/2023
# Mr. Singh
# M.D Cardiology
# Phase 2, Urban Estate
# Reg. No. 102003
# 58732892378
# Mr. Singh
# M.D Cardiology
# Reg. No. 102003
#  Made by Prescription MakerInvestigations
# Advice/Referrals
# Advice/Referrals
# Notes
# Notes

# %%
file_path = '/content/Schedule.png'
extracted_text = extract_text_from_file(file_path)
print(extracted_text)
# Out:
#
#
# Schedule
#
#
#
# Time & Venue :
# ¢ Offline - 09:00 to 13:00 | Monday to Friday | TAN Audi
# ¢ Online - 15:00 to 18:00 | Monday to Friday | Zoom
# Note : (1) Be on Time (2) Bring your Laptop (3) Bring power extensions (if possible)
# Brief Schedule:
# ¢ Week 1 | 05 - 09 June 2023 | Basics of Python, OOPs and Problem-Solving using Python, Pandas, Numpy, Scipy
# ¢ Week 2 | 12 - 16 June 2023 | Machine Learning, Optimization and Statistics, Mini Projects
# ¢ Week 3 | 19 - 23 June 2023 | Web Development - Basics (HTML, CSS, Bootstrap, Javascript, ReactJS, Express and MongoDB)
# ¢ Week 4 | 26 - 30 June 2023 | Web Development - Advance (NextJS, Django, Hosting, ML Model Deployment, Crud)
# ¢ Week 5 | 03 - 07 July 2023 | Deep Learning for Image Processing and Natural Language Processing (NLP)
# ¢ Week 6 | 10 - 14 July 2023 | Time Series, Internet of Things (loT), Cloud Services, Generative Al, Valedictory, Certificate distribution

# %%
file_path = '/content/merged_data.csv'
extracted_text = extract_text_from_file(file_path)
print(extracted_text)
# Out:
# Name	RAM	ROM	Sold Quantity	Rating
# POCO M4 5G	4	64	79482	4.2
# APPLE iPhone 13	0	128	227342	4.7
# APPLE iPhone 13	0	128	227342	4.7
# APPLE iPhone 13	0	128	227342	4.7
# POCO M4 5G	4	64	79482	4.2
# vivo T2 5G	8	128	4978	4.4
# APPLE iPhone 13	0	128	227342	4.7
# SAMSUNG Galaxy F14 5G	6	128	17115	4.2
# Infinix Note 12 Pro 5G	8	128	28073	4.1
# Infinix Note 12 Pro 5G	8	128	28073	4.1
# SAMSUNG Galaxy F23 5G	6	128	195602	4.3
# POCO X5 Pro 5G	8	256	8229	4.3
# POCO M4 5G	4	64	79482	4.2
# realme 10 Pro 5G	8	128	19487	4.3
# realme 10 Pro 5G	6	128	26570	4.3
# realme GT 2	8	128	10142	4.3
# realme GT 2	8	128	10142	4.3
# Google Pixel 6a	6	128	47692	4.3
# Google Pixel 6a	6	128	47692	4.3
# realme 10 Pro 5G	6	128	26570	4.3
# realme 10 Pro 5G	8	128	19487	4.3
# realme 10 Pro 5G	6	128	26570	4.3
# realme 10 Pro 5G	8	128	19487	4.3
# SAMSUNG Galaxy F23 5G	6	128	195602	4.3

# %%
extracted_text
# Out:
# 'Name\tRAM\tROM\tSold Quantity\tRating\nPOCO M4 5G\t4\t64\t79482\t4.2\nAPPLE iPhone 13\t0\t128\t227342\t4.7\nAPPLE iPhone 13\t0\t128\t227342\t4.7\nAPPLE iPhone 13\t0\t128\t227342\t4.7\nPOCO M4 5G\t4\t64\t79482\t4.2\nvivo T2 5G\t8\t128\t4978\t4.4\nAPPLE iPhone 13\t0\t128\t227342\t4.7\nSAMSUNG Galaxy F14 5G\t6\t128\t17115\t4.2\nInfinix Note 12 Pro 5G\t8\t128\t28073\t4.1\nInfinix Note 12 Pro 5G\t8\t128\t28073\t4.1\nSAMSUNG Galaxy F23 5G\t6\t128\t195602\t4.3\nPOCO X5 Pro 5G\t8\t256\t8229\t4.3\nPOCO M4 5G\t4\t64\t79482\t4.2\nrealme 10 Pro 5G\t8\t128\t19487\t4.3\nrealme 10 Pro 5G\t6\t128\t26570\t4.3\nrealme GT 2\t8\t128\t10142\t4.3\nrealme GT 2\t8\t128\t10142\t4.3\nGoogle Pixel 6a\t6\t128\t47692\t4.3\nGoogle Pixel 6a\t6\t128\t47692\t4.3\nrealme 10 Pro 5G\t6\t128\t26570\t4.3\nrealme 10 Pro 5G\t8\t128\t19487\t4.3\nrealme 10 Pro 5G\t6\t128\t26570\t4.3\nrealme 10 Pro 5G\t8\t128\t19487\t4.3\nSAMSUNG Galaxy F23 5G\t6\t128\t195602\t4.3'

# %% [markdown]
# #8
# ##Replace \n and \t with space

# %%
text = extracted_text.replace('\n', ' ').replace('\t', ' ')
print(text)
# Out:
# Name RAM ROM Sold Quantity Rating POCO M4 5G 4 64 79482 4.2 APPLE iPhone 13 0 128 227342 4.7 APPLE iPhone 13 0 128 227342 4.7 APPLE iPhone 13 0 128 227342 4.7 POCO M4 5G 4 64 79482 4.2 vivo T2 5G 8 128 4978 4.4 APPLE iPhone 13 0 128 227342 4.7 SAMSUNG Galaxy F14 5G 6 128 17115 4.2 Infinix Note 12 Pro 5G 8 128 28073 4.1 Infinix Note 12 Pro 5G 8 128 28073 4.1 SAMSUNG Galaxy F23 5G 6 128 195602 4.3 POCO X5 Pro 5G 8 256 8229 4.3 POCO M4 5G 4 64 79482 4.2 realme 10 Pro 5G 8 128 19487 4.3 realme 10 Pro 5G 6 128 26570 4.3 realme GT 2 8 128 10142 4.3 realme GT 2 8 128 10142 4.3 Google Pixel 6a 6 128 47692 4.3 Google Pixel 6a 6 128 47692 4.3 realme 10 Pro 5G 6 128 26570 4.3 realme 10 Pro 5G 8 128 19487 4.3 realme 10 Pro 5G 6 128 26570 4.3 realme 10 Pro 5G 8 128 19487 4.3 SAMSUNG Galaxy F23 5G 6 128 195602 4.3

# %% [markdown]
# #9 - Homework
# a) Search online for text written image dataset or use the below given dataset.
#
# - https://www.kaggle.com/datasets/mehaksingal/personal-financial-dataset-for-india
#
# b) Modify above code to upload a zip file.
#
# c) Unzip the file
#
# d) Add loops or any other method to read mutiple files at a time
#
# e) Output must be extracted text stored in any format (list, sets etc)

# %%
import zipfile
import os
import textract

# def extract_text_from_file(file_path):
#     text = textract.process(file_path)
#     return text.decode('utf-8')

def unzip_and_process(zip_file_path):
    # Unzip the file
    extracted_folder = 'extracted_files'
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extracted_folder)

    print('Zip file extracted successfully.')

    # Iterate over each extracted file
    for root, dirs, files in os.walk(extracted_folder):
        for file in files:
            file_path = os.path.join(root, file)
            # Call the function to process each file
            extracted_text = extract_text_from_file(file_path)
            print(extracted_text)

    print('Processing of all files completed.')

# Provide the path to the zip file
zip_file_path = '/content/ezyzip.zip'

# Call the function to unzip and process the files
unzip_and_process(zip_file_path)
# Out:
# Zip file extracted successfully.
#
#
# COMPANY NAME
# Pay Slip Oct 2022
#
#
#
#
#
# Special Allowances
#
# Employee Name Total Working Days 31
#
# Employee ID LOP Days 0
# Designation Paid Days 31
# Department Bank Name Axis Bank
# Date of Joining Bank A/c No 5412XXXX20
# Gross Sala’
#
# Earnings
#
#
#
# Basic Salary 9000
#
# House Rent Allowances 3600
# Conveyance Allowances 1600
#
# Medical Allowances 1250
#
# Special Allowances 4550
#
# Gross Sala’ 20000
#
# 20000
#
# Amount in Words: Eighteen Thousand Rupee
#
#
#
#
#
#
#
# LATCH SECURE Pane K1D- vO /er8 2610
#
#
#
# dorel de LA Canara Bank
#
# 2
#
# Rupees ead
#
# |, wer -B12001
#
# Bhagalpur, Collectorate aa|sp
# 2013 MSHC) IFSC : CNRB0008661 IFSC Code DODOMMYYYY
#
# Valid for three months only from the date of instrument
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Ha.
# Alc. No.
#
#
#
#
#
#
#
#
#
# “Payable at par at all our Branches in India”
#
# Cheque Number
#
#
#
# wh aed? ai
#
#
#
# 64c0250038
#
#
#
#
#
#
#
#
#
# sree
#
#
#
#
#
#
#
# MICR Code 32
#
#
#
# Karen Art Studio Smith John ssn XXXXX-3128 Period Beginning 6/9/2010
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1134 Main Stet 1123 River Road GrossPay SI28RS6——Paiod Ending 6/172010
# Louisville KY 40211 Louisville. KY #20 NePay $989.79 CheckDae™ 172010
# (602) 25234 Fling States M3 (Chock No 100
# Taming Towra ‘Amount VI Rmt TaxevDeducins Aout VID Ani
# Salary si2ss.a6 128646 Fed Income’. s10s23 10823
# Overtime 0 $0.00 S00 Socil Security Tax ST678 $7678
# Bonus soon S00 Malice Tax Si796 i796
# Commissions s000 0.00 State rcome Tax $64.70 $6470
# Tips 0.00 $0.00 Lgcal Income Tax 0.00 S000
# Gross Pay STIG SU2HR4G Health Insurance 315.00 sis0
# 401K $50.00 $50.00
# Net Pay $559.79 $959.79
# Karen Art Studio Smith John ssn XXXXX-3123Patod Beginning 6132010
# 1134 Main Stet 23 River Road GrossPay $128B6——Paviod Ending 6/172010
# Louis, KY 40211 Louise. KY 42011 NePay 95979 Check Dee” 6/172010
# (602) 125.234 Fling Stas MB (Check No 1000
# TowRae Amowt ———VIDAmt Tues Delucions Aaount VID Ant
# si2ss.6 $1288.46 Fol Income'Tax 10423 s10423
# oo $0.00 Socal Security Tax S168 ST678
# Medicare Tax 81796 31796
# Slate Income Tax 64.70 36470
# Local come Ta ‘so.00 30.00
# eh Insurance sis.00 $15.00
# 40k $50.00 $50.00
# NetPay 3959.79 9397
# ‘
# Karen Art Studio My Bank No. 1000
# 1134 Main Stet 123 Bank Road eave
# Louisville, KY 40211
# (502) 123-1234 CHENG
#
#
#
# Pay To THE john sy
# ‘Gree Gree coin Saar so AS ee 8 Pree
#
# [Nine Hundred Ffty-Nine Dollars and 79/100
# John Smith
#
# 1123 River Road
# Louisville, KY 42011
#
# Memo: _PayCheck  seomrrrannescusincerasensicr Ge
# OOOO0 OOOH 2223456 7890223456 79"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company Kame
# ay Sip tor Oot 27
#
#
#
#
#
#
#
#
#
# Toate
#
# Jab national bank
#
#
#
# wWE?77ELM 2500240078
#
# Ferre es —_— i bons
#
#
#
# Enkay tndte
# Fokay edecoumend cation
#
#
#
# Employer Code # 1000110
#
#
#
#
#
#
#
#
# Salary Slip for the Month of Wty 196
#
#
#
#
#
#
#
#
#
# = SANL GORAL MADATHTL Denar tant 5 # NORKENNIG
# 2 18/530 4NEHRU NAGAR ‘Team a ie
# KURA (EAST) Dale of Uoinine » 18/07/96
# : NUNBAT
#
# WUWEAL 400 024
#
#
#
# Basic 1,516.00
# HRA, 377.00 =
# Conveyance 700.00 5
# cca 0.00, r
# --Educetian Allow. - —— 100.00 Te seat nae Tage 3 as
# DA 0.00 ;
# / .Medical 76.00
# Wiscellanecus 9.00
#
#
#
# Tot.Workina Days
# Tot-Days Absent
# Tot-Dhys Present :
#
#
#
#
#
#
# Current Basic % 831.00 i “prot. Tax
# Current HRA + 208-00 Income lax > 0.00
# Br ineenct Conv. “ Loan Deduct.
#
# Other Dedyet.
#
# Pray. Fund
#
# FP Fund
#
# prs
#
#
#
# Date 3 08/08/96
#
#
#
#
# WIN MEDICARE PRIVATE LIMITED.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Company Name
#
# pay Slip For The Month of
#
# 2021
#
#
#
# Employee Name:
# Email 1D :
# Contact No:
#
# Gender:
#
# Grade:
#
# Department :
#
# Location :
#
# Bank A/C No:
#
# Bank Name :
#
# LOP Days:
#
# Standard Day:
#
#
#
# Refund Dayas :
#
#
#
#
#
# Earnings
#
# Monthly Rate
#
# Current Month
#
# Arrears
#
# Total
#
# Deductors
#
# Total
#
#
#
# Bsic Salary
#
# Profession Tax
#
#
#
# Conveyance Allowance
#
# Group Insurance
#
#
#
# HRA
#
# Provident Fund
#
#
#
# Fixed Allowance
#
# Income Tax
#
#
#
# Leave Travel Allowance
#
#
#
# Medical
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Total :
#
#
#
# Net Salaray Payable:
#
#
#
#
#
# Net Salary Payable (In Words) :
#
#
#
#
#
# Employe Signture :
#
# Employee Signature :
#
#
#
#
#
#
#
#
#
#
#
#
#
# Department of Posts wat AD
# Pay Slip for the month of September 2021 ae iat
# Name Office :
# Empid Level-Index —;_-03-01
# Designation - PostMan PAN 7
#
# GPF / PRAN No
#
# |_Deduetions [Out Of Accoung
# NPS Contribution 2778.00\Prof.Tax —|——200.00)
# 1375.00 |PM's Relief Fund
#
# Recreation Club
# subscript
# nion/Association 75.00
# Subscri
# 4163.00
# Take Home Pay: Rs. 27,584.00 /-
#
# TWENTY SEVEN THOUSAND FIVE HUNDRED EIGHTY FOUR Rupees Only.
#
#
#
#
#
#
#
#
#
#
# o
# S
# a
# o>
# So
#
#
#
#
#
# Below are the details of Break -up for the Out of account
#
# 100,00
#
# 75.00
#
#
#
#
#
# Department of Posts
#
# for the month of July 2022 re
#
#
#
# ome
# : Leveltndex
# + Mail Guard PAN E
# GPE /PRAN No:
#
#
#
# 03.06
#
#
#
#
# Baral Deductions ‘Out OF Account
# wie Pay 725200.00 NPS Contribution 3377.00
#
# jarness Allowance 3568.00]
#
# 1A on TPA (612.00
#
# fouse Rent Allowance | __4536.00|CGEGIS Savings Fund 30.00
# Transport Allowance 1800.00|CGHS. 250.00
#
# Total 4576.00] 18451.00 Total 30100]
#
# ‘Take Home Pay: Rs. 27,215.00 /-
# -qwENTY SEVEN THOUSAND TWO HUNDRED FIETEES Rupees Oa
#
#
#
#
#
#
#
#
#
# exceltemplate.NET
#
#
#
# SALARY SLIP
#
#
#
# CONFIDENTIAL
#
#
#
#
#
#
#
#
#
#
#
#
#
# January 2017
# Name : Wayne Doorprize Title : Cleaning Service Staff
# Employee ID a Directorate 2 Operation
# Department : General Affairs
#
# Deeg eure) Der ead
# Basic Salary 2,000.00
# Meal Allowance 300.00
# Transportation Allowance 300.00
# Medical Allowance 300.00
# Retirement Insurance 25.00
# Fax 25.00
# Total 2,900.00 50.00
# Payment Date January 28, 2017
# Bank Name Bank of America 2,850.00
# Bank Account Name Wayne Doorprize
#
# Bank Account # 1234567890
#
#
#
#
#
# Two Thousand Eight Hundred Fifty Dollars
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# File Home Insert Draw Page Layout Formulas Data Review \
#
#
#
#
#
# Vv Ely S| Calibri vii. vy} B
#
# 132 y Se
# A B Cc D E
#
#
#
#
#
#
#
# (Company Name: ) Pay Advice for Month of
#
#
#
#
#
#
#
#
#
#
#
#
# Employee#__ Name Department
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3 Designation Salary for
#
# 4 |Pay & Allowances {Amounts |Deductions Other Details
# 5 |Basic 5000|PF-Counter 150|PF Count Bal
# 6 |House Rent 450|Other DED 2 260
#
# 7 |Conveyance 600}EOBI-DED 300
#
# 8 |C.LA. 340]Others 6
#
# 9 |Medical 230
#
# 10 |Other All 70
#
# 11 |Special 1200
#
# 12 |Over Time 1400
#
# 13 [Arrears
#
# 14 |Bonus
#
# 15 |Gross Total 11390}Total DED
#
#
#
#
#
# Salary Credited to Your Account#
#
# Bank Name Branch
#
#
#
#
#
# 20 Accountant Financial Manager Chief Executive
#
# SALARY SLIP
#
#
#
# MAY
#
# 2018
#
#
#
# ‘Employes Name:
# Employee Designation:
#
# Tacob Sma
# Cleaning Staff
# ‘General Affairs
#
#
#
#
#
# [Leave Taken
#
#
#
# [Days Worked:
#
#
#
#
#
# [Description
#
#
#
# Fax]
#
#
#
# Tasurance|
#
#
#
# Advance|
#
#
#
#
#
#
#
#
#
# 'S6350.00,
#
# Total
#
# ‘SIS50.00,
#
#
#
# 'S4.700.00
#
# Four Thousand Seven Hundred Dollars.
#
#
#
#
#
# ‘01-06-2018.
#
# [Account Holder Name
#
# Jacob Smith
#
#
#
# ABC BANK
#
#
#
# [Account Number
#
# 9876543210
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PR HOB FINANGIAL SERVICES UMITED
# bo?) = Bears
#
# te
#
# Payslip for the month of March 2019
#
#
#
#
#
#
#
# Erployee Code wo8s2207 Bank Name DFC Bank
# Employee Name An Siegh Bank Account Number 0100080686476
#
# Verical ‘Cotecton Services Permanent Account Number BEHPAGATA
#
# AN Number 100477280462 Function Telecaling
#
# Account Number uvigano049611000000378 Fesion Nort
#
# tie Account Nunbee rrtesassea Date ot Joining 20 Fob 2015
#
# cay Now Debi Days Worked 2
#
# Branch Vicaspur wwe °
#
# Rote ual Oteor ‘Avoars Days 0
#
# Grace ste
#
# Eamings Deductions
#
# Parteulars Rates/Month ‘Amount Cumulative | Particulars ‘Amount Cumulative
# Basie Salary 5,000.00 5000.00 160,000.00 | Provident Fund 600.00 7,200.00
# Conveyance 4,300.00 1,500.00 1730000 | esIc 419.00 4187.00
# poe {Give Inga Deduction 7500 300.00
# roars OF oo 700.00
#
# Siowehee”
#
# Mouse Rent 2,000.00 2.00.00 24,000.00
#
# Otter Allowance 7,400.00 7400.00 81,400.00
#
# ‘rears Ober 000 7,400.00
#
# Blorance
#
# Special Allowance 0.00 7,100.00
#
# ‘roars Of Specie! 000 71000
#
# Incentive Bonus 0.00 40,000.00
#
# Total Earrings 15,900.00 15,900.00 230,800.00 | Total Deductions 7,094.00 71.898.
#
#
#
#
#
#
#
# Net Salary : 14,808.00
# Inwords : Fourteen Thousand Eight Hundred Six Only (All Amount isin &)
#
#
#
#
#
#
#
# Salary Slip Template
#
# Company Name é.
#
# (Write Street Address Here]
#
# Salary Slip
#
# Employee Name:
#
#
#
# Designation:
# Month: Year:
#
#
#
#
#
# Earnings | | Deductions.
# Basic 2 BA
# HAA
#
# Com=ysrc=
#
#
#
# eee | Proyigtent Fund MMW
#
#
#
# DIARRA <e¥KKE
#
#
#
# ARRARK
#
#
#
#
#
#
#
# Tots Addition XXEREMRKMAMK | Tote! Gecuctlor HNN IO
#
# NET Salary HOARHKIIKN,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Dollars Eight Thousand Two Rundred Twenty Two Only
#
# Cheques:
# Dated As:
#
# Bank Name Here:
#
#
#
#
#
# Employee Signature Director
#
#
#
# SAG INFOTECH PVT LTD
# 458, BASEMENT, ACHARYA KRIPLANI MARG, BEES DUKAN JAIPUR-202004
# HARYANA
# Phone :0141-2226006 e-Mail: info@saginfotechcom
# Web-Site: www.saginfotech com
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PAY SLIP
#
# EmploeeNare =ABE Cage o00e
#
# Fatners Name Dov ooar2021
#
# Pan Bank AeNo.
#
# ESIAC No Na, Branch
#
# Deparment BLED SAWING Designation
#
# Jcstegory UNIVERSAL, Seale a
#
# Bank Name Pay Node TRANSFER
#
# Sender MALE Adress (Pam)
#
# shit Wort Location
#
# van Asghar No,
#
# ont Dae a Total Paid Day a
#
# lWeskiyor ° Max Payable Daye 24
#
# Le 5 NetPsid Days 26
#
# Earnings “Amount Rs. Dedustions mount Rs:
#
# BASIC SALARY 58800 FF 7800.09
#
# HRA 2.79600
#
# TRANSPORT ALLOW ANCE, 141800
#
# MEDICAL ALLOWANCE 87400
#
# LEAVE TRAVEL ALLOWANCE 9800
#
# WARRIOUS ALLOWANCE. 3.19700,
#
# [otal Earnings 76,573.00 Total Deductions 0000)
#
# NetPay = As TSETSOO
#
# InWords __: Rs. Thirteen Thousand Eight Hundred Seventy Three Only
#
# [Employers Contribution (CTC)
#
# GROSS EARNING TeETaa|
#
# ENPLOYER'S PROVIDENT FUND 1800.09
#
# > PENSION FUND i
# > PROVIDENTFUND 1300.09
#
# IENPLOYER'S STATE INSURANCE nil
# Tolar TTATE.09
#
# HTotarTC = Re. 47A7a.00
#
# InVords _: Rs. Seventeen Thousand Four Hundred Seventy Three Only
#
#
#
#
#
# iiizeeTaneous Information
#
#
#
#
#
#
#
# (GROSS SALARY EBT:
#
#
#
# Processing of all files completed.
